# %%
import jax
import jax.numpy as jnp
from jax.scipy.stats import gaussian_kde
from jax.scipy.optimize import minimize
from jax.scipy.special import logsumexp
import numpy as np
import mcmc_infinity as mc
import emcee
import corner

import matplotlib.pyplot as plt
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

seed = 12345

# %% [markdown]
# # Target Distribution
#
# Here we try to sample a $d=2$ dimensional Rosenbrock
# banana function with log-PDF given by
#
# $$ \log f(x) = -\sum_{i=1}^{d-1} ( 100 (x_{i+1}-x_{i}^2)^2 + (1-x_{i})^2 ) + c, $$
#
# where $c$ is an unknown normalisation constant.

# %%
dim = 2

target = mc.test_functions.rosenbrock.Rosenbrock(dim=dim)

# %%
x = np.linspace(-1, 3, 300)
y = np.linspace(-1, 7, 300)
X, Y = np.meshgrid(x, y)
Z = target(np.stack((X,Y), axis=-1))

fig, ax = plt.subplots(figsize=(4,5))

levels = np.linspace(-10, 0, 11)
c = ax.contourf(X, Y, Z, levels=levels)
cbar = plt.colorbar(c)

ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_title("2D Rosenbrock Banana")
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# # Uniform Proposal
#
# Create a uniform proposal distribution with the prior bounds.

# %%
bounds = np.array([[-1.0, 3.0], [-1.0, 7.0]])

uniform_proposal = mc.uniform_proposal.UniformProposal(dim, bounds)

# %% [markdown]
# Initialise the perfect sampler.

# %%
sampler_uniform = mc.sampler.PerfectSampler(target, 
                                            uniform_proposal, 
                                            np.array([[1.]*dim]), 
                                            seed=seed)

# %% [markdown]
# Run the perfect sampler. This will be quite slow because the uniform proposal is inefficient; we will explore more efficient KDE proposals below.

# %%
T = 2

num_samples = 1000

samples_uniform, T_uniform = sampler_uniform.get_perfect_samples(T, 
                                                                num_samples, 
                                                                return_T=True)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]/Users/christophermoore/miniconda3/envs/mcmc_infinity/lib/python3.13/site-packages/jax/_src/ops/scatter.py:93: FutureWarning: scatter inputs have incompatible types: cannot safely cast value from dtype=float64 to dtype=int32 with jax_numpy_dtype_promotion='standard'. In future JAX releases this will result in an error.
#   warnings.warn(
# 100%|██████████| 1000/1000 [04:17<00:00,  3.88it/s]

# %%
corner.corner(np.array(samples_uniform), ranges=bounds, labels=['x1','x2'])
plt.show()

# %% [markdown]
# We also run a normal MCMC using this proposal just to check the acceptance probability.

# %%
_, a = sampler_uniform.evolve_chain(jnp.ones(dim), 10000)

print(f"Acceptance rate: {a:.2f}")
# Out:
# Acceptance rate: 0.02

# %% [markdown]
# # KDE Proposal
#
# We will first run an MCMC using the _emcee_ package.
# We use 100 walkers, a burnin of 100, then 10000 iterations.
# Thinning by a factor of 1000 leaves 1000 approximately i.i.d. samples.
# These samples do NOT have to be perfect.
#
# We will use these samples to build our proposal.

# %%
"""
# initialise emcee walker positions uniformly within prior bounds
nwalkers = 100
x0 = np.random.uniform(size=(nwalkers, dim))
x0 = bounds[:,0] + x0 * (bounds[:,1] - bounds[:,0])

# initialize the sampler
sampler = emcee.EnsembleSampler(nwalkers, dim, target)

# run burn-in
sampler.run_mcmc(x0, 100, progress=True)
sampler.reset()

# run analysis chains 
sampler.run_mcmc(x0, 10000, progress=True)
print(f"Mean acceptance fraction: {np.mean(sampler.acceptance_fraction):.3f}")
print(f"Mean autocorrelation time: {np.mean(sampler.get_autocorr_time(tol=5)):.3f}")

samples = sampler.get_chain(flat=True, thin=1000)
"""

samples = np.loadtxt("rosenbrock_demo_emcee_samples.txt")
print(f"Number of samples after burn-in and thinning: {len(samples)}")

corner.corner(samples, ranges=bounds, labels=['x1','x2'])

plt.show()
# Out:
# Number of samples after burn-in and thinning: 1000

# %% [markdown]
# We now build KDEs that we will use as our proposal.
#
# It is necessary to inflate (i.e. make wider) the KDEs in order for $P/Q$ to have a clear global maximum. Smaller inflation will make the objective function harder to maximise but will yield a more efficient proposal. Conversely, a larger inflation will make the objective function easier to maximise at the cost of a less efficient proposal.

# %%
Qkde_small = mc.kde_proposal.KernelDensityEstimateProposal(dim, 
                 inflation_scale=1.5)
Qkde_small.fit(samples)

Qkde_big = mc.kde_proposal.KernelDensityEstimateProposal(dim, 
                 inflation_scale=3.0)
Qkde_big.fit(samples)

# %% [markdown]
# We now use the _jax.scipy_ to optimise the objective functions $P/Q$.

# %%
def maximize_objective_func(seed, PoverQ, num_trials):
    
    sol = minimize(lambda x: -PoverQ(x), jnp.ones(dim), 
                   method="BFGS", tol=1.e-3)

    x_hat = sol.x
    logP_max = -sol.fun

    for i in range(num_trials):
        x = jax.random.uniform(jax.random.PRNGKey(seed + i), 
                               shape=(dim,), 
                               minval=bounds[:,0], 
                               maxval=bounds[:,1])
        
        sol_test = minimize(lambda x: -PoverQ(x), jnp.ones(dim), 
                   method="BFGS", tol=1.e-5)

        if -sol_test.fun > logP_max:
            print("New maximum found!")
            x_hat = sol_test.x
            logP_max = -sol_test.fun
            sol = sol_test

    return sol

# %%
num_trials = 20

sol_small = maximize_objective_func(0, lambda x: target(x)-Qkde_small.logP(x), 
                                    num_trials)

print(f"Solution small: {sol_small.x}, logP: {target(sol_small.x)}")

sol_big = maximize_objective_func(0, lambda x: target(x)-Qkde_big.logP(x), 
                                    num_trials)

print(f"Solution big: {sol_big.x}, logP: {target(sol_big.x)}")
# Out:
# Solution small: [1.12513907 1.26496594], logP: -0.015754261879819615
# Solution big: [1.02496879 1.04997407], logP: -0.0006578918128707919

# %% [markdown]
# Initialise the perfect samplers using the KDE proposals.

# %%
sampler_kde_small = mc.sampler.PerfectSampler(target, 
                                            Qkde_small, 
                                            jnp.atleast_2d(sol_small.x), 
                                            seed=seed)

sampler_kde_big = mc.sampler.PerfectSampler(target, 
                                            Qkde_big, 
                                            jnp.atleast_2d(sol_big.x), 
                                            seed=seed)

# %% [markdown]
# Perform the perfect sampling.

# %%
samples_kde_small, T_kde_small = sampler_kde_small.get_perfect_samples(T, 
                                                                num_samples, 
                                                                return_T=True)

samples_kde_big, T_kde_big = sampler_kde_big.get_perfect_samples(T, 
                                                                 num_samples, 
                                                                 return_T=True)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]/Users/christophermoore/miniconda3/envs/mcmc_infinity/lib/python3.13/site-packages/jax/_src/ops/scatter.py:93: FutureWarning: scatter inputs have incompatible types: cannot safely cast value from dtype=float64 to dtype=int32 with jax_numpy_dtype_promotion='standard'. In future JAX releases this will result in an error.
#   warnings.warn(
# 100%|██████████| 1000/1000 [00:53<00:00, 18.83it/s]
# 100%|██████████| 1000/1000 [02:12<00:00,  7.56it/s]

# %%
corner.corner(np.array(samples_kde_small), ranges=bounds, labels=['x1','x2'])
plt.show()

# %%
corner.corner(np.array(samples_kde_big), ranges=bounds, labels=['x1','x2'])
plt.show()

# %% [markdown]
# We also run some normal MCMC chains using these proposals to look at the acceptance rates.

# %%
_, a = sampler_kde_small.evolve_chain(jnp.ones(dim), 10000)

print(f"Acceptance rate (KDE small): {a:.2f}")

_, a = sampler_kde_big.evolve_chain(jnp.ones(dim), 10000)

print(f"Acceptance rate (KDE large): {a:.2f}")
# Out:
# Acceptance rate (KDE small): 0.10
# Acceptance rate (KDE large): 0.05

# %% [markdown]
# # Plotting
#
# This plot compares the efficieny of the three perfect sampling runs performed in this notebook.
#
# The small KDE proposal is the most efficient because (on average) it achives coupling with the smallest values of $T$. Conversely, the uniform proposal is the least effecient because it needs the largest $T$ values (on average) to couple.

# %%
fig, ax = plt.subplots(figsize=(4,3))

ax.hist(jnp.log2(T_kde_small), histtype='stepfilled', alpha=0.5, density=True,
        color='0.9', edgecolor='k', linewidth=1.5, hatch='||', linestyle=':',
        bins=0.5+np.arange(0, 10), label=r'$Q_{\rm KDE}$')
ax.text(1.5, 0.3, r"$(I=1.5)$")

ax.hist(jnp.log2(T_kde_big), histtype='step', density=True,
        color='black', linestyle='--', linewidth=1.5,
        bins=0.5+np.arange(0, 10), label=r'$Q_{\rm KDE}$')
ax.text(4.75, 0.3, r"$(I=3.0)$")

ax.hist(jnp.log2(T_uniform), histtype='stepfilled', alpha=0.5, density=True,
        color='0.9', edgecolor='k', linewidth=1.5, hatch='//',
        bins=0.5+np.arange(0, 10), label=r'$Q_{\rm uniform}$')

ax.set_xticks(np.arange(0, 11))
ax.set_xlim(0, 10)
ax.set_ylim(0, 0.37)
ax.set_xticklabels([r"$2^{"+str(i)+"}$" for i in np.arange(0, 11)])

ax.set_xlabel(r"Stepping back $T_{\rm max}$")
ax.set_ylabel("Frequency")

ax.legend(loc='upper center', ncols=3, labelspacing=0,  
          handlelength=2, frameon=False)

plt.show()

# %% [markdown]
# This plot demonstrates the binary stepping back approach to achieve coupling.

# %%
import seaborn as sns

colors = sns.color_palette('colorblind', 4)

colors
# Out:
# [(0.00392156862745098, 0.45098039215686275, 0.6980392156862745),
#  (0.8705882352941177, 0.5607843137254902, 0.0196078431372549),
#  (0.00784313725490196, 0.6196078431372549, 0.45098039215686275),
#  (0.8352941176470589, 0.3686274509803922, 0.0)]

# %%
my_seed = 14

initial_positions = np.array([[float(sol_small.x[0]), float(sol_small.x[1])],
                            [0.0, 0.3],
                            [2.0, 4.5],
                            [-0.5,0.0]])

print(target(initial_positions) - Qkde_small.logP(initial_positions)[0])

sampler_demo = mc.sampler.PerfectSampler(target, 
                                        Qkde_small, 
                                        initial_positions,
                                        seed=my_seed)

one_perfect_sample, chains = sampler_demo.get_perfect_sample(2, 
                                                        show_all_output=True)

print(f"Length of the longest chain {chains[-1].shape[1]}")

fig, ax = plt.subplots(figsize=(4,3))

num_walkers = len(initial_positions)


for c, chain in enumerate(chains[::-1]):
    for w in range(num_walkers):
        if True:
            PQ = target(chain[w]) - Qkde_small.logP(chain[w])
            iter = np.arange(1-len(PQ),1)
            ax.plot(iter, PQ, color=colors[w], lw=1+0.5*c, alpha=0.6)
        else:
            pass
        
ax.set_xlim(-32, 1.4)
ax.set_xticks([-32,-16, -8, -4, -2, 0])

y_val = target(chains[-1][0][-1]) - Qkde_small.logP(chains[-1][0][-1])
ax.scatter([0.9], [y_val], s=15, marker='+', color='C0', alpha=1)

ax.set_xlabel(r"Iteration")
ax.set_ylabel(r"Objective function $\log(P/Q)$")

plt.show()
# Out:
# [  1.29501845  -8.68922729 -24.68922729  -7.18922729]
# Length of the longest chain 32

# %% [markdown]
# Finally, this plot shows the target distribution, with some samples overlaid.
#
# The colored square markers show the starting locations of the chains in the above binary stepping back plot with matching colors.

# %%
grid_points = jnp.stack((X,Y)).T
grid_points = jnp.reshape(grid_points, (-1, 2))

kde_grid_vals = Qkde_small.kde.logpdf(grid_points.T)
kde_grid_vals = jnp.reshape(kde_grid_vals, X.shape)
kde_small_marg_y = jnp.exp(logsumexp(kde_grid_vals, axis=0))
kde_small_marg_y = num_samples * kde_small_marg_y / jnp.sum(kde_small_marg_y)
kde_small_marg_x = jnp.exp(logsumexp(kde_grid_vals, axis=1))
kde_small_marg_x = num_samples * kde_small_marg_x / jnp.sum(kde_small_marg_x)

kde_grid_vals = Qkde_big.kde.logpdf(grid_points.T)
kde_grid_vals = jnp.reshape(kde_grid_vals, X.shape)
kde_big_marg_y = jnp.exp(logsumexp(kde_grid_vals, axis=0))
kde_big_marg_y = num_samples * kde_big_marg_y / jnp.sum(kde_big_marg_y)
kde_big_marg_x = jnp.exp(logsumexp(kde_grid_vals, axis=1))
kde_big_marg_x = num_samples * kde_big_marg_x / jnp.sum(kde_big_marg_x)

# %%
import matplotlib.gridspec as gridspec

bin_width = 0.1

# Custom sizes for rows and columns
widths = [4, 1]     # Column 0 and 1 widths
heights = [1, 8]    # Row 0 and 1 heights

fig = plt.figure(figsize=(0.6*5, 0.6*9))
gs = gridspec.GridSpec(2, 2, 
                       width_ratios=widths, height_ratios=heights, 
                       wspace=0.1, hspace=0.05)

# Lower left corner (row=1, col=0)
ax00 = fig.add_subplot(gs[1, 0])
ax00.contour(X, Y, Z, levels=[-20, -5, -1], colors=['gray'], 
             linestyles=['-'], alpha=0.4)
ax00.scatter(samples_uniform[0:100,0], samples_uniform[0:100,1], 
             s=2, color='k', alpha=0.4)
ax00.scatter([one_perfect_sample[0]], [one_perfect_sample[1]],
             s=30, color='C0', alpha=1, marker='+')
ax00.set_xlim(bounds[0])
ax00.set_ylim(bounds[1])
ax00.set_xlabel(r'$\textit{\textbf{x}}_1$')
ax00.set_ylabel(r'$\textit{\textbf{x}}_2$')
ax00.set_xticks(np.arange(bounds[0,0], bounds[0,1]+1,1))
ax00.set_yticks(np.arange(bounds[1,0], bounds[1,1]+1,1))

for m in range(4):
    ax00.scatter(initial_positions[m,0], initial_positions[m,1], 
                 s=30, color=colors[m], alpha=1, marker='s')

# Lower right (row=1, col=1)
ax01 = fig.add_subplot(gs[1, 1], sharey=ax00)
counts, bins = np.histogram(samples_uniform[:,1],
                            bins=np.arange(bounds[1,0], bounds[1,1], bin_width))
bin_centers = 0.5 * (bins[:-1] + bins[1:])
ax01.barh(bin_centers, counts, height=(bins[1] - bins[0]), 
          color='gray', alpha=0.6)
ax01.plot(kde_small_marg_y/bin_width, y, color='0.5', lw=1, ls=':')
ax01.plot(kde_big_marg_y/bin_width, y, color='k', lw=1, ls='--')

# Upper left (row=0, col=0)
ax10 = fig.add_subplot(gs[0, 0], sharex=ax00)
counts, bins = np.histogram(samples_uniform[:,0], 
                            bins=np.arange(bounds[0,0], bounds[0,1], bin_width))
bin_centers = 0.5 * (bins[:-1] + bins[1:])
ax10.bar(bin_centers, counts, width=(bins[1] - bins[0]), 
         color='gray', alpha=0.6)
ax10.plot(x, kde_small_marg_x/bin_width, color='0.5', lw=1, ls=':')
ax10.plot(x, kde_big_marg_x/bin_width, color='k', lw=1, ls='--')

# Hide all ticks and labels on upper-left and lower-right
for ax in [ax10, ax01]:
    ax.tick_params(axis='both', which='both',
                   bottom=False, left=False, labelbottom=False, labelleft=False)

plt.show()

# %%
inflation_values = np.logspace(jnp.log10(1.2), 1.0, 100)[::-1]

distance_values = np.zeros_like(inflation_values)

initial_guess = jnp.ones(dim)

for i, inflation_scale in enumerate(inflation_values):
    Qkde_test = mc.kde_proposal.KernelDensityEstimateProposal(dim, 
                    inflation_scale=inflation_scale)
    Qkde_test.fit(samples)

    sol_test = minimize(lambda x: -(target(x)-Qkde_test.logP(x)), 
                jnp.ones(dim), method="BFGS", tol=1.e-5)
    
    initial_guess = sol_test.x

    print(f"{inflation_scale=:.2f} , {sol_test.x=}, logP={float(sol_test.fun):.2f}")
    
    distance_values[i] = jnp.linalg.norm(sol_test.x - jnp.ones(dim))
# Out:
# inflation_scale=10.00 , sol_test.x=Array([1.00224266, 1.00439049], dtype=float64), logP=-4.37
# inflation_scale=9.79 , sol_test.x=Array([1.00233669, 1.00457541], dtype=float64), logP=-4.33
# inflation_scale=9.58 , sol_test.x=Array([1.00243502, 1.00476881], dtype=float64), logP=-4.29
# inflation_scale=9.38 , sol_test.x=Array([1.00253789, 1.0049712 ], dtype=float64), logP=-4.25
# inflation_scale=9.18 , sol_test.x=Array([1.00264556, 1.0051831 ], dtype=float64), logP=-4.21
# inflation_scale=8.98 , sol_test.x=Array([1.00275833, 1.00540508], dtype=float64), logP=-4.17
# inflation_scale=8.79 , sol_test.x=Array([1.00287648, 1.00563775], dtype=float64), logP=-4.13
# inflation_scale=8.61 , sol_test.x=Array([1.00300033, 1.00588172], dtype=float64), logP=-4.09
# inflation_scale=8.43 , sol_test.x=Array([1.00313021, 1.00613764], dtype=float64), logP=-4.05
# inflation_scale=8.25 , sol_test.x=Array([1.00326645, 1.0064062 ], dtype=float64), logP=-4.01
# inflation_scale=8.07 , sol_test.x=Array([1.0034094, 1.0066881], dtype=float64), logP=-3.97
# inflation_scale=7.90 , sol_test.x=Array([1.00355943, 1.00698406], dtype=float64), logP=-3.93
# inflation_scale=7.73 , sol_test.x=Array([1.0037169 , 1.00729484], dtype=float64), logP=-3.89
# inflation_scale=7.57 , sol_test.x=Array([1.00388219, 1.0076212 ], dtype=float64), logP=-3.85
# inflation_scale=7.41 , sol_test.x=Array([1.0040557 , 1.00796391], dtype=float64), logP=-3.81
# inflation_scale=7.25 , sol_test.x=Array([1.00423828, 1.00832471], dtype=float64), logP=-3.77
# inflation_scale=7.10 , sol_test.x=Array([1.00442951, 1.00870277], dtype=float64), logP=-3.73
# inflation_scale=6.95 , sol_test.x=Array([1.00463017, 1.00909966], dtype=float64), logP=-3.69
# inflation_scale=6.80 , sol_test.x=Array([1.00484067, 1.00951622], dtype=float64), logP=-3.65
# inflation_scale=6.66 , sol_test.x=Array([1.00506143, 1.00995328], dtype=float64), logP=-3.61
# inflation_scale=6.52 , sol_test.x=Array([1.00529286, 1.0104117 ], dtype=float64), logP=-3.57
# inflation_scale=6.38 , sol_test.x=Array([1.00553538, 1.01089233], dtype=float64), logP=-3.53
# inflation_scale=6.24 , sol_test.x=Array([1.00578941, 1.01139603], dtype=float64), logP=-3.49
# inflation_scale=6.11 , sol_test.x=Array([1.00605537, 1.01192366], dtype=float64), logP=-3.45
# inflation_scale=5.98 , sol_test.x=Array([1.00633368, 1.01247609], dtype=float64), logP=-3.41
# inflation_scale=5.85 , sol_test.x=Array([1.00662477, 1.01305418], dtype=float64), logP=-3.38
# inflation_scale=5.73 , sol_test.x=Array([1.00692905, 1.01365881], dtype=float64), logP=-3.34
# inflation_scale=5.61 , sol_test.x=Array([1.00724696, 1.01429086], dtype=float64), logP=-3.30
# inflation_scale=5.49 , sol_test.x=Array([1.00757891, 1.01495121], dtype=float64), logP=-3.26
# inflation_scale=5.37 , sol_test.x=Array([1.00792534, 1.01564076], dtype=float64), logP=-3.22
# inflation_scale=5.26 , sol_test.x=Array([1.00828668, 1.01636041], dtype=float64), logP=-3.18
# inflation_scale=5.15 , sol_test.x=Array([1.00866337, 1.01711108], dtype=float64), logP=-3.15
# inflation_scale=5.04 , sol_test.x=Array([1.00905586, 1.01789368], dtype=float64), logP=-3.11
# inflation_scale=4.93 , sol_test.x=Array([1.00946458, 1.01870918], dtype=float64), logP=-3.07
# inflation_scale=4.83 , sol_test.x=Array([1.00989001, 1.01955854], dtype=float64), logP=-3.03
# inflation_scale=4.73 , sol_test.x=Array([1.01033262, 1.02044275], dtype=float64), logP=-3.00
# inflation_scale=4.63 , sol_test.x=Array([1.01079287, 1.02136283], dtype=float64), logP=-2.96
# inflation_scale=4.53 , sol_test.x=Array([1.01127129, 1.02231985], dtype=float64), logP=-2.92
# inflation_scale=4.43 , sol_test.x=Array([1.01176837, 1.0233149 ], dtype=float64), logP=-2.89
# inflation_scale=4.34 , sol_test.x=Array([1.01228467, 1.02434913], dtype=float64), logP=-2.85
# inflation_scale=4.25 , sol_test.x=Array([1.01282074, 1.02542375], dtype=float64), logP=-2.81
# inflation_scale=4.16 , sol_test.x=Array([1.01337718, 1.02654   ], dtype=float64), logP=-2.78
# inflation_scale=4.07 , sol_test.x=Array([1.0139546 , 1.02769924], dtype=float64), logP=-2.74
# inflation_scale=3.98 , sol_test.x=Array([1.01455367, 1.02890286], dtype=float64), logP=-2.71
# inflation_scale=3.90 , sol_test.x=Array([1.01517508, 1.03015235], dtype=float64), logP=-2.67
# inflation_scale=3.81 , sol_test.x=Array([1.01581956, 1.03144929], dtype=float64), logP=-2.64
# inflation_scale=3.73 , sol_test.x=Array([1.0164879 , 1.03279535], dtype=float64), logP=-2.60
# inflation_scale=3.65 , sol_test.x=Array([1.0171809 , 1.03419231], dtype=float64), logP=-2.57
# inflation_scale=3.58 , sol_test.x=Array([1.01790657, 1.03565659], dtype=float64), logP=-2.53
# inflation_scale=3.50 , sol_test.x=Array([1.01865406, 1.03716613], dtype=float64), logP=-2.50
# inflation_scale=3.43 , sol_test.x=Array([1.01942975, 1.03873413], dtype=float64), logP=-2.46
# inflation_scale=3.35 , sol_test.x=Array([1.02023489, 1.04036323], dtype=float64), logP=-2.43
# inflation_scale=3.28 , sol_test.x=Array([1.0210708, 1.0420563], dtype=float64), logP=-2.39
# inflation_scale=3.21 , sol_test.x=Array([1.02193892, 1.04381645], dtype=float64), logP=-2.36
# inflation_scale=3.15 , sol_test.x=Array([1.02284082, 1.04564702], dtype=float64), logP=-2.33
# inflation_scale=3.08 , sol_test.x=Array([1.02377824, 1.04755185], dtype=float64), logP=-2.29
# inflation_scale=3.01 , sol_test.x=Array([1.02475291, 1.04953459], dtype=float64), logP=-2.26
# inflation_scale=2.95 , sol_test.x=Array([1.02576683, 1.05159964], dtype=float64), logP=-2.23
# inflation_scale=2.89 , sol_test.x=Array([1.02682216, 1.05375164], dtype=float64), logP=-2.19
# inflation_scale=2.83 , sol_test.x=Array([1.02792121, 1.05599567], dtype=float64), logP=-2.16
# inflation_scale=2.77 , sol_test.x=Array([1.02906656, 1.05833727], dtype=float64), logP=-2.13
# inflation_scale=2.71 , sol_test.x=Array([1.03026091, 1.06078236], dtype=float64), logP=-2.10
# inflation_scale=2.65 , sol_test.x=Array([1.03150728, 1.06333756], dtype=float64), logP=-2.07
# inflation_scale=2.59 , sol_test.x=Array([1.03280905, 1.06601024], dtype=float64), logP=-2.03
# inflation_scale=2.54 , sol_test.x=Array([1.03417   , 1.06880865], dtype=float64), logP=-2.00
# inflation_scale=2.49 , sol_test.x=Array([1.03559448, 1.07174232], dtype=float64), logP=-1.97
# inflation_scale=2.43 , sol_test.x=Array([1.03708769, 1.07482257], dtype=float64), logP=-1.94
# inflation_scale=2.38 , sol_test.x=Array([1.03865091, 1.07805273], dtype=float64), logP=-1.91
# inflation_scale=2.33 , sol_test.x=Array([1.04029458, 1.08145518], dtype=float64), logP=-1.88
# inflation_scale=2.28 , sol_test.x=Array([1.04202378, 1.08504132], dtype=float64), logP=-1.85
# inflation_scale=2.23 , sol_test.x=Array([1.04384625, 1.08882822], dtype=float64), logP=-1.82
# inflation_scale=2.19 , sol_test.x=Array([1.04577132, 1.09283645], dtype=float64), logP=-1.79
# inflation_scale=2.14 , sol_test.x=Array([1.04780845, 1.09708704], dtype=float64), logP=-1.76
# inflation_scale=2.09 , sol_test.x=Array([1.04997006, 1.10160747], dtype=float64), logP=-1.73
# inflation_scale=2.05 , sol_test.x=Array([1.0522703 , 1.10642917], dtype=float64), logP=-1.70
# inflation_scale=2.01 , sol_test.x=Array([1.05472584, 1.11158926], dtype=float64), logP=-1.67
# inflation_scale=1.96 , sol_test.x=Array([1.05735645, 1.11713186], dtype=float64), logP=-1.64
# inflation_scale=1.92 , sol_test.x=Array([1.06018559, 1.12310955], dtype=float64), logP=-1.61
# inflation_scale=1.88 , sol_test.x=Array([1.06324126, 1.12958527], dtype=float64), logP=-1.58
# inflation_scale=1.84 , sol_test.x=Array([1.06655742, 1.13663575], dtype=float64), logP=-1.56
# inflation_scale=1.80 , sol_test.x=Array([1.07017392, 1.14435147], dtype=float64), logP=-1.53
# inflation_scale=1.76 , sol_test.x=Array([1.0741398 , 1.15284445], dtype=float64), logP=-1.50
# inflation_scale=1.73 , sol_test.x=Array([1.07851434, 1.16225098], dtype=float64), logP=-1.47
# inflation_scale=1.69 , sol_test.x=Array([1.08337113, 1.17274139], dtype=float64), logP=-1.44
# inflation_scale=1.65 , sol_test.x=Array([1.08879903, 1.18452346], dtype=float64), logP=-1.42
# inflation_scale=1.62 , sol_test.x=Array([1.0949115 , 1.19786447], dtype=float64), logP=-1.39
# inflation_scale=1.59 , sol_test.x=Array([1.10185251, 1.21310723], dtype=float64), logP=-1.36
# inflation_scale=1.55 , sol_test.x=Array([1.10981121, 1.23070649], dtype=float64), logP=-1.34
# inflation_scale=1.52 , sol_test.x=Array([1.11904736, 1.25129294], dtype=float64), logP=-1.31
# inflation_scale=1.49 , sol_test.x=Array([1.12993366, 1.27578067], dtype=float64), logP=-1.28
# inflation_scale=1.46 , sol_test.x=Array([1.14307749, 1.30566741], dtype=float64), logP=-1.26
# inflation_scale=1.42 , sol_test.x=Array([1.15433162, 1.3315077 ], dtype=float64), logP=-1.23
# inflation_scale=1.39 , sol_test.x=Array([1.15626904, 1.33558432], dtype=float64), logP=-1.21
# inflation_scale=1.36 , sol_test.x=Array([1.24331324, 1.54504987], dtype=float64), logP=-1.18
# inflation_scale=1.34 , sol_test.x=Array([1.17258773, 1.37341559], dtype=float64), logP=-1.16
# inflation_scale=1.31 , sol_test.x=Array([1.15446042, 1.33079185], dtype=float64), logP=-1.13
# inflation_scale=1.28 , sol_test.x=Array([1.21616957, 1.47730199], dtype=float64), logP=-1.11
# inflation_scale=1.25 , sol_test.x=Array([1.7669151 , 3.11055242], dtype=float64), logP=-1.17
# inflation_scale=1.23 , sol_test.x=Array([1.18536512, 1.40252556], dtype=float64), logP=-1.06
# inflation_scale=1.20 , sol_test.x=Array([2.31392258, 5.34566544], dtype=float64), logP=-1.59

# %%
fig, ax = plt.subplots(figsize=(4,3))
ax.plot(inflation_values, distance_values)
ax.axvline(1.5, color='k', linestyle=':')
ax.axvline(3.0, color='k', linestyle=':')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r"KDE Inflation scale $I$")
ax.set_ylabel(r"Distance")
plt.show()
